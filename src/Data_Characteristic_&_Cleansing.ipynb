# %%
#a. Performing exploratory analysis on the data to understand the patterns

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec 
import seaborn as sns

# %%
# data = constant_data.DataConstant
dataset = pd.read_excel("../Data/Womens Clothing Reviews Data.xlsx")
dataset
# Out:
#        Product ID        Category Subcategory1 SubCategory2   Location  \
# 0             767       Initmates     Intimate    Intimates     Mumbai
# 1            1080         General      Dresses      Dresses  Bangalore
# 2            1077         General      Dresses      Dresses    Gurgaon
# 3            1049  General Petite      Bottoms        Pants    Chennai
# 4             847         General         Tops      Blouses  Bangalore
# ...           ...             ...          ...          ...        ...
# 23481        1104  General Petite      Dresses      Dresses    Gurgaon
# 23482         862  General Petite         Tops        Knits    Gurgaon
# 23483        1104  General Petite      Dresses      Dresses    Gurgaon
# 23484        1084         General      Dresses      Dresses    Gurgaon
# 23485        1104  General Petite      Dresses      Dresses    Chennai
#
#       Channel  Customer Age  \
# 0      Mobile            33
# 1      Mobile            34
# ...

# %%
dataset.shape
# Out:
# (23486, 11)

# %%
dataset.head()
# Out:
#    Product ID        Category Subcategory1 SubCategory2   Location Channel  \
# 0         767       Initmates     Intimate    Intimates     Mumbai  Mobile
# 1        1080         General      Dresses      Dresses  Bangalore  Mobile
# 2        1077         General      Dresses      Dresses    Gurgaon  Mobile
# 3        1049  General Petite      Bottoms        Pants    Chennai     Web
# 4         847         General         Tops      Blouses  Bangalore     Web
#
#    Customer Age             Review Title  \
# 0            33                      NaN
# 1            34                      NaN
# 2            60  Some major design flaws
# 3            50         My favorite buy!
# 4            47         Flattering shirt
#
#                                          Review Text  Rating  Recommend Flag
# 0  Absolutely wonderful - silky and sexy and comf...       4               1
# 1  Love this dress!  it's sooo pretty.  i happene...       5               1
# ...

# %%
#Make columns names in proper format by assigning proper variables
dataset.columns=['Product_ID', 'Category', 'SubCategory1', 'SubCategory2', 'Location',
       'Channel', 'Customer_Age', 'Review_Title', 'Review_Text', 'Rating',
       'Recommend_Flag']

# %%
dataset.head()
# Out:
#    Product_ID        Category SubCategory1 SubCategory2   Location Channel  \
# 0         767       Initmates     Intimate    Intimates     Mumbai  Mobile
# 1        1080         General      Dresses      Dresses  Bangalore  Mobile
# 2        1077         General      Dresses      Dresses    Gurgaon  Mobile
# 3        1049  General Petite      Bottoms        Pants    Chennai     Web
# 4         847         General         Tops      Blouses  Bangalore     Web
#
#    Customer_Age             Review_Title  \
# 0            33                      NaN
# 1            34                      NaN
# 2            60  Some major design flaws
# 3            50         My favorite buy!
# 4            47         Flattering shirt
#
#                                          Review_Text  Rating  Recommend_Flag
# 0  Absolutely wonderful - silky and sexy and comf...       4               1
# 1  Love this dress!  it's sooo pretty.  i happene...       5               1
# ...

# %%
#Check columns name 
dataset.columns
# Out:
# Index(['Product_ID', 'Category', 'SubCategory1', 'SubCategory2', 'Location',
#        'Channel', 'Customer_Age', 'Review_Title', 'Review_Text', 'Rating',
#        'Recommend_Flag'],
#       dtype='object')

# %%
# Find duplicate rows
duplicated_rows = dataset.duplicated()

# Count the number of duplicate rows
number_of_duplicate_rows = duplicated_rows.sum()

print("Number of duplicated rows:", number_of_duplicate_rows)
# Out:
# Number of duplicated rows: 3

# %%
#Remove duplicate data
dataset=dataset.drop_duplicates()

# %%
dataset.shape
# Out:
# (23483, 11)

# %%
# Validate with duplicate rows again
duplicated_rows = dataset.duplicated()

# Count the number of duplicate rows
number_of_duplicate_rows = duplicated_rows.sum()

print("Number of duplicated rows:", number_of_duplicate_rows)
# Out:
# Number of duplicated rows: 0

# %%
#Check null values in dataset
dataset.isnull().sum()
# Out:
# Product_ID           0
# Category            14
# SubCategory1        14
# SubCategory2        14
# Location             0
# Channel              0
# Customer_Age         0
# Review_Title      3807
# Review_Text        842
# Rating               0
# Recommend_Flag       0
# dtype: int64

# %%
rows_missing_category = dataset[dataset['Category'].isnull()]
# Display rows with missing 'Category' as a DataFrame
rows_missing_category
# Out:
#        Product_ID Category SubCategory1 SubCategory2   Location Channel  \
# 9444           72      NaN          NaN          NaN    Chennai     Web
# 13767         492      NaN          NaN          NaN    Gurgaon     Web
# 13768         492      NaN          NaN          NaN     Mumbai     Web
# 13787         492      NaN          NaN          NaN    Chennai     Web
# 16216         152      NaN          NaN          NaN  Bangalore  Mobile
# 16221         152      NaN          NaN          NaN  Bangalore  Mobile
# 16223         152      NaN          NaN          NaN    Gurgaon  Mobile
# 18626         184      NaN          NaN          NaN     Mumbai     Web
# 18671         184      NaN          NaN          NaN    Chennai  Mobile
# 20088         772      NaN          NaN          NaN    Gurgaon     Web
# 21532         665      NaN          NaN          NaN    Gurgaon  Mobile
# 22997         136      NaN          NaN          NaN     Mumbai  Mobile
# ...

# %%
dataset['Category'].fillna(dataset['Category'].mode()[0], inplace=True)
dataset['SubCategory1'].fillna(dataset['SubCategory1'].mode()[0], inplace=True)
dataset['SubCategory2'].fillna(dataset['SubCategory2'].mode()[0], inplace=True)
# Out:
# C:\Users\Raksa Kun\AppData\Local\Temp\ipykernel_1728\757871235.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['Category'].fillna(dataset['Category'].mode()[0], inplace=True)
# C:\Users\Raksa Kun\AppData\Local\Temp\ipykernel_1728\757871235.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['SubCategory1'].fillna(dataset['SubCategory1'].mode()[0], inplace=True)
# C:\Users\Raksa Kun\AppData\Local\Temp\ipykernel_1728\757871235.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
dataset.loc[dataset['Product_ID']==492]
# Out:
#        Product_ID Category SubCategory1 SubCategory2 Location Channel  \
# 13767         492  General         Tops      Dresses  Gurgaon     Web
# 13768         492  General         Tops      Dresses   Mumbai     Web
# 13787         492  General         Tops      Dresses  Chennai     Web
#
#        Customer_Age     Review_Title  \
# 13767            23         So soft!
# 13768            49  Wardrobe staple
# 13787            48              NaN
#
#                                              Review_Text  Rating  \
# 13767  I just love this hoodie! it is so soft and com...       5
# 13768  Love this hoodie. so soft and goes with everyt...       5
# 13787                                                NaN       5
#
#        Recommend_Flag
# 13767               1
# 13768               1
# 13787               1

# %%
dataset.isnull().sum()
# Out:
# Product_ID           0
# Category             0
# SubCategory1         0
# SubCategory2         0
# Location             0
# Channel              0
# Customer_Age         0
# Review_Title      3807
# Review_Text        842
# Rating               0
# Recommend_Flag       0
# dtype: int64

# %%
rows_missing_Review_Text  = dataset[dataset['Review_Text'].isnull()]
# Display rows with missing 'Review_Text ' as a DataFrame
rows_missing_Review_Text
# Out:
#        Product_ID        Category SubCategory1 SubCategory2 Location Channel  \
# 92            861  General Petite         Tops        Knits  Gurgaon  Mobile
# 93           1081         General      Dresses      Dresses  Gurgaon  Mobile
# 98           1133         General      Jackets    Outerwear   Mumbai  Mobile
# 135           861  General Petite         Tops        Knits  Gurgaon     Web
# 142          1126         General      Jackets    Outerwear  Gurgaon     Web
# ...           ...             ...          ...          ...      ...     ...
# 23224        1087  General Petite      Dresses      Dresses   Mumbai  Mobile
# 23258         862         General         Tops        Knits   Mumbai     Web
# 23301         862         General         Tops        Knits   Mumbai     Web
# 23303         823         General         Tops      Blouses   Mumbai  Mobile
# 23470        1104  General Petite      Dresses      Dresses  Gurgaon     Web
#
# ...

# %%
# remove rows where Review_Title and Review_Text have NaN values
dataset.dropna(subset=['Review_Title', 'Review_Text'], how='all', inplace=True)
# Out:
# C:\Users\Raksa Kun\AppData\Local\Temp\ipykernel_1728\566270713.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.dropna(subset=['Review_Title', 'Review_Text'], how='all', inplace=True)

# %%
dataset.isnull().sum()
# Out:
# Product_ID           0
# Category             0
# SubCategory1         0
# SubCategory2         0
# Location             0
# Channel              0
# Customer_Age         0
# Review_Title      2966
# Review_Text          1
# Rating               0
# Recommend_Flag       0
# dtype: int64

# %%
rows_missing_Review_Text  = dataset[dataset['Review_Text'].isnull()]
# Display rows with missing 'Review_Text ' as a DataFrame
rows_missing_Review_Text
# Out:
#        Product_ID Category SubCategory1 SubCategory2 Location Channel  \
# 10220        1096  General      Dresses      Dresses  Chennai  Mobile
#
#        Customer_Age             Review_Title Review_Text  Rating  \
# 10220            30  Such a beautiful dress!         NaN       5
#
#        Recommend_Flag
# 10220               1

# %%
rows_missing_Review_Title  = dataset[dataset['Review_Title'].isnull()]
# Display rows with missing 'Review_Text ' as a DataFrame
rows_missing_Review_Title
# Out:
#        Product_ID        Category SubCategory1 SubCategory2   Location  \
# 0             767       Initmates     Intimate    Intimates     Mumbai
# 1            1080         General      Dresses      Dresses  Bangalore
# 11           1095  General Petite      Dresses      Dresses     Mumbai
# 30           1060  General Petite      Bottoms        Pants     Mumbai
# 36           1002         General      Bottoms       Skirts     Mumbai
# ...           ...             ...          ...          ...        ...
# 23425         430       Initmates     Intimate    Intimates     Mumbai
# 23435         262  General Petite     Intimate       Lounge     Mumbai
# 23450         964         General      Jackets      Jackets     Mumbai
# 23453        1104  General Petite      Dresses      Dresses    Gurgaon
# 23458         862  General Petite         Tops        Knits  Bangalore
#
#       Channel  Customer_Age Review_Title  \
# 0      Mobile            33          NaN
# ...

# %%
import pandas as pd

# Replace "NaN" values in both columns with empty strings
dataset['Review_Text'].fillna('', inplace=True)
dataset['Review_Title'].fillna('', inplace=True)

# Merge the columns and store the result in a new column called "Merged_Review"
dataset['Merged_Review'] = dataset['Review_Title'] + ' ' + dataset['Review_Text']

# Drop the individual "Review_Text" and "Review_Title" columns if needed
dataset.drop(['Review_Text', 'Review_Title'], axis=1, inplace=True)
# Out:
# C:\Users\Raksa Kun\AppData\Local\Temp\ipykernel_1728\984468918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['Review_Text'].fillna('', inplace=True)
# C:\Users\Raksa Kun\AppData\Local\Temp\ipykernel_1728\984468918.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['Review_Title'].fillna('', inplace=True)
# C:\Users\Raksa Kun\AppData\Local\Temp\ipykernel_1728\984468918.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
dataset.isnull().sum()
# Out:
# Product_ID        0
# Category          0
# SubCategory1      0
# SubCategory2      0
# Location          0
# Channel           0
# Customer_Age      0
# Rating            0
# Recommend_Flag    0
# Merged_Review     0
# dtype: int64

# %%
dataset.loc[dataset['Product_ID']==767]
# Out:
#     Product_ID   Category SubCategory1 SubCategory2 Location Channel  \
# 0          767  Initmates     Intimate    Intimates   Mumbai  Mobile
# 13         767  Initmates     Intimate    Intimates  Gurgaon  Mobile
#
#     Customer_Age  Rating  Recommend_Flag  \
# 0             33       4               1
# 13            44       5               1
#
#                                         Merged_Review
# 0    Absolutely wonderful - silky and sexy and com...
# 13  Runs big Bought the black xs to go under the l...

# %%
dataset.shape
# Out:
# (22642, 10)

# %%
#Check info 
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22642 entries, 0 to 23485
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Product_ID      22642 non-null  int64
#  1   Category        22642 non-null  object
#  2   SubCategory1    22642 non-null  object
#  3   SubCategory2    22642 non-null  object
#  4   Location        22642 non-null  object
#  5   Channel         22642 non-null  object
#  6   Customer_Age    22642 non-null  int64
#  7   Rating          22642 non-null  int64
#  8   Recommend_Flag  22642 non-null  int64
#  9   Merged_Review   22642 non-null  object
# dtypes: int64(4), object(6)
# memory usage: 1.9+ MB

# %%
dataset.describe()
# Out:
#          Product_ID  Customer_Age        Rating  Recommend_Flag
# count  22642.000000  22642.000000  22642.000000    22642.000000
# mean     919.340164     43.279790      4.183597        0.818876
# std      202.265815     12.327023      1.115751        0.385129
# min        1.000000     18.000000      1.000000        0.000000
# 25%      861.000000     34.000000      4.000000        1.000000
# 50%      936.000000     41.000000      5.000000        1.000000
# 75%     1078.000000     52.000000      5.000000        1.000000
# max     1205.000000     99.000000      5.000000        1.000000

# %%
dataset.columns
# Out:
# Index(['Product_ID', 'Category', 'SubCategory1', 'SubCategory2', 'Location',
#        'Channel', 'Customer_Age', 'Rating', 'Recommend_Flag', 'Merged_Review'],
#       dtype='object')

# %%
# Value counts for 'Category'
category_counts = dataset['Category'].value_counts()
print("Value Counts for Category:")
print(category_counts)
# Out:
# Value Counts for Category:
# General           13379
# General Petite     7837
# Initmates          1426
# Name: Category, dtype: int64

# %%
# Value counts for 'SubCategory1'
subcategory1_counts = dataset['SubCategory1'].value_counts()
print("Value Counts for SubCategory1:")
print(subcategory1_counts)
# Out:
# Value Counts for SubCategory1:
# Tops        10061
# Dresses      6146
# Bottoms      3662
# Intimate     1653
# Jackets      1002
# Trend         118
# Name: SubCategory1, dtype: int64

# %%
# Value counts for 'SubCategory2'
subcategory2_counts = dataset['SubCategory2'].value_counts()
print("Value Counts for SubCategory2:")
print(subcategory2_counts)
# Out:
# Value Counts for SubCategory2:
# Dresses           6159
# Knits             4626
# Blouses           2983
# Sweaters          1380
# Pants             1350
# Jeans             1104
# Fine gauge        1059
# Skirts             903
# Jackets            683
# Lounge             669
# Swim               332
# Outerwear          319
# Shorts             304
# Sleep              214
# Legwear            158
# Intimates          147
# Layering           132
# Trend              118
# Casual bottoms       1
# Chemises             1
# Name: SubCategory2, dtype: int64

# %%
# Value counts for 'Location'
Location_counts = dataset['Location'].value_counts()
print("Value Counts for Location:")
print(Location_counts)
# Out:
# Value Counts for Location:
# Gurgaon      8491
# Mumbai       6859
# Bangalore    5050
# Chennai      2242
# Name: Location, dtype: int64

# %%
# Value counts for 'Channel'
Channel_counts = dataset['Channel'].value_counts()
print("Value Counts for Channel:")
print(Channel_counts)
# Out:
# Value Counts for Channel:
# Web       13096
# Mobile     9546
# Name: Channel, dtype: int64

# %%
# Value counts for 'Customer_Age'
Customer_Age_counts = dataset['Customer_Age'].value_counts()
print("Value Counts for Customer_Age:")
print(Customer_Age_counts)
# Out:
# Value Counts for Customer_Age:
# 39    1226
# 35     851
# 36     801
# 34     766
# 38     751
#       ...
# 93       2
# 90       2
# 86       2
# 99       2
# 92       1
# Name: Customer_Age, Length: 77, dtype: int64

# %%
# Value counts for 'Recommend_Flag'
Recommend_Flag_counts = dataset['Recommend_Flag'].value_counts()
print("Value Counts for Recommend_Flag:")
print(Recommend_Flag_counts)
# Out:
# Value Counts for Recommend_Flag:
# 1    18541
# 0     4101
# Name: Recommend_Flag, dtype: int64

# %%
# Value counts for 'Rating'
Rating_counts = dataset['Rating'].value_counts()
print("Value Counts for Rating:")
print(Rating_counts)
# Out:
# Value Counts for Rating:
# 5    12541
# 4     4908
# 3     2823
# 2     1549
# 1      821
# Name: Rating, dtype: int64

# %%
#Check the correlation between numerical features.
dataset.corr()
# Out:
# C:\Users\Raksa Kun\AppData\Local\Temp\ipykernel_1728\3955366760.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataset.corr()
#                 Product_ID  Customer_Age    Rating  Recommend_Flag
# Product_ID        1.000000      0.017646 -0.018425       -0.014855
# Customer_Age      0.017646      1.000000  0.029926        0.034184
# Rating           -0.018425      0.029926  1.000000        0.792570
# Recommend_Flag   -0.014855      0.034184  0.792570        1.000000

# %%
# Save the cleaned dataset to a new CSV file
dataset.to_excel('Womens Clothing Reviews Data New.xlsx', index=False)
